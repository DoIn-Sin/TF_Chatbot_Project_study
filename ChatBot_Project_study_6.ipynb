# %% [markdown]
# # RNN
# ### 순환 신경망으로 불리며, 앞서 배운 신경망 모델과 다르게 은닉층 노드의 출력값을 출력층과 그 다음 시점의 은닉층 노드의 입력으로 전달해 순환하는 특성을 가지고 있다.
# ### RNN에서 은닉층 노드는 이전 시점의 상탯값을 저장하는 메모리 역할을 수행하기 때문에 이것을 셀 또는 메모리 셀이라고 부른다. 은닉층의 메모리 셀의 출력 벡터는 출력층과 다음 시점의 메모리 세렝 전달되는데 이를 은닉 상태라고 한다.
# ### RNN에서 가장 중요한 점은 현재 시점의 메모리 셀이 이전 시점의 은닉 상태 값에 영향을 받으며 완전한 연결 계층 구조를 가지고 있다는 점이다.
# ### RNN의 모델 종류는 입력 개수와 출력 개수에 따라 구분한다.
# #### many-to-one : 여러 개의 입력을 받아 하나의 출력을 내는 모델이다. 자연어 처리 분야에서는 메일 제목을 입력받아 메일이 스팸인지 아닌지 판단하는 모델로 사용가능하다.
# #### one-to-many : 하나의 입력을 받아 여러 개의 출력을 내는 모델이다. 이것은 자연어 처리 분야에서는 잘 사용하지 않고, 주로 한 장의 이미지를 입력받아 이미지를 설명하는 텍스트를 출력하는 모델로 사용한다.
# #### many-to-many : 여러 개의 입력을 받아 여러 개의 출력을 내는 모델이다. 이 모델은 앞으로 구현할 개체명 인식기에 주로 사용하는 모델이다. 단어 시퀀스를 입력으로 받아 각 시퀀스가 의미하는 개체명을 출력하는 구조이다. 또한 한국어를 입력받아 영어로 출력하는 번역기 모델로도 사용가능하다.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, LSTM, SimpleRNN

# %%
# n_timestep만큼 시퀀스 데이터 분리
def split_sequence(sequence, step):
    x, y = list(), list()

    for i in range(len(sequence)):
        end_idx = i + step
        if end_idx > len(sequence) - 1:
            break

        seq_x, seq_y = sequence[i:end_idx], sequence[end_idx]
        x.append(seq_x)
        y.append(seq_y)

    return np.array(x), np.array(y)

# %%
# sin 함수 학습 데이터
x = [i for i in np.arange(start=-10, # 시작 범위는 -10
                          stop=10,    # 끝은 +10 까지
                          step=0.1)]  # 위와같은 x축 범위를 가지는 sin함수의 값을 0.1씩 증가
train_y = [np.sin(i) for i in x] # 0.1씩 증가시킨 sin함수 값을 저장

# %%
# 하이퍼파라미터
n_timesteps = 15 # 입력 시퀀스 길이를 15로 함. 이때, 15개의 메모리 셀이 생성됨
n_features = 1 # 입력 벡터의 차원은 1로 정의

# %%
# 시퀀스 나누기
# 파라미터 값 형태는 아래와 같다.
# train_x.shape => (samples, timesteps)
# train_y.shape => (samples)
train_x, train_y = split_sequence(train_y, step=n_timesteps) # sin파형의 데이터가 들어있는 trian_y에서 입력 시퀀스 길이(15)만큼
                                                             # 나눠서 입력 시퀀스를 생성한다.
print("shape x:{} / y:{}".format(train_x.shape, train_y.shape))
# Out:
# shape x:(185, 15) / y:(185,)

# %% [markdown]
# ##### 케라스에서 RNN 계층을 사용하려면 3차원이어야 하므로 현재 2차인 trian_x(samples, n_timestep)을 데이터 형상에 맞게 3차원(batch size, time step, input length) 형태로 변환해야한다.

# %%
# RNN 입력 벡터 크기를 맞추기 위해 벡터 차원 크기 변경
# reshape from [samples, timesteps] into [samples, timesteps, features]
# batch size = samples
train_x = train_x.reshape(train_x.shape[0], train_x.shape[1], n_features)
print("train_x.shape = {}".format(train_x.shape))
print("train_y.shape = {}".format(train_y.shape))
# Out:
# train_x.shape = (185, 15, 1)
# train_y.shape = (185,)

# %%
# RNN 모델 정의
model = Sequential()
model.add(SimpleRNN(units=10, # RNN 계층에 존재하는 전체 뉴런 수
                    return_sequences=False, # 은닉 상태 값 출력 여부 (True = 모든 과정 출력,  False = 마지막 시점 출력)
                    input_shape=(n_timesteps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# #### early stop : 오버피팅을 피하기 위해 loss값이 갑자기 증가되는 시점을 찾아 조기 종료 함.

# %%
# 모델 학습
np.random.seed(0)
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='loss', patience=5, mode='auto') # patience=5로 설정, 성능이 증가하지 않을 때 5번 더 학습
history = model.fit(train_x, train_y, epochs=1000, callbacks=[early_stopping])
# Out:
# Epoch 1/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0604
# Epoch 2/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.8729
# Epoch 3/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7179
# Epoch 4/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5905
# Epoch 5/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4857
# Epoch 6/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4006
# Epoch 7/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3325
# Epoch 8/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2768
# Epoch 9/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2324
# Epoch 10/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1954
# Epoch 11/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1667
# Epoch 12/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1418
# Epoch 13/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1220
# Epoch 14/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1050
# Epoch 15/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0906
# Epoch 16/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0784
# Epoch 17/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0677
# Epoch 18/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0578
# Epoch 19/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0491
# Epoch 20/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0409
# Epoch 21/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0334
# Epoch 22/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0274
# Epoch 23/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0228
# Epoch 24/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0196
# Epoch 25/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 26/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0163
# Epoch 27/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0152
# Epoch 28/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0142
# Epoch 29/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0133
# Epoch 30/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0124
# Epoch 31/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0115
# Epoch 32/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0107
# Epoch 33/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0099
# Epoch 34/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0092
# Epoch 35/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0084
# Epoch 36/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 37/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0070
# Epoch 38/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0064
# Epoch 39/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0057
# Epoch 40/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0051
# Epoch 41/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 42/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0041
# Epoch 43/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 44/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 45/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 46/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 47/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 48/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 49/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 50/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 51/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 52/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 53/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 54/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 55/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 56/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 9.8315e-04
# Epoch 57/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 9.3840e-04
# Epoch 58/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 9.0286e-04
# Epoch 59/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 8.6217e-04
# Epoch 60/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 8.2917e-04
# Epoch 61/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 7.9592e-04
# Epoch 62/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 7.7001e-04
# Epoch 63/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 7.4200e-04
# Epoch 64/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 7.1788e-04
# Epoch 65/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.9519e-04
# Epoch 66/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.7493e-04
# Epoch 67/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.5223e-04
# Epoch 68/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.3447e-04
# Epoch 69/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.0925e-04
# Epoch 70/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.9207e-04
# Epoch 71/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.7473e-04
# Epoch 72/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.5577e-04
# Epoch 73/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.3779e-04
# Epoch 74/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.1990e-04
# Epoch 75/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.0519e-04
# Epoch 76/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.9157e-04
# Epoch 77/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.7414e-04
# Epoch 78/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.5900e-04
# Epoch 79/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.4424e-04
# Epoch 80/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.3121e-04
# Epoch 81/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.1652e-04
# Epoch 82/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.0424e-04
# Epoch 83/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.9460e-04
# Epoch 84/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.7940e-04
# Epoch 85/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.6568e-04
# Epoch 86/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.5548e-04
# Epoch 87/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.4480e-04
# Epoch 88/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.3288e-04
# Epoch 89/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.2402e-04
# Epoch 90/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.1276e-04
# Epoch 91/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.0601e-04
# Epoch 92/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.9341e-04
# Epoch 93/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.8416e-04
# Epoch 94/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.7455e-04
# Epoch 95/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.6789e-04
# Epoch 96/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.5904e-04
# Epoch 97/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.5205e-04
# Epoch 98/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.4369e-04
# Epoch 99/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3503e-04
# Epoch 100/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3034e-04
# Epoch 101/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.2247e-04
# Epoch 102/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1440e-04
# Epoch 103/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.0797e-04
# Epoch 104/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.0271e-04
# Epoch 105/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9500e-04
# Epoch 106/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9069e-04
# Epoch 107/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.8453e-04
# Epoch 108/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.8068e-04
# Epoch 109/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7384e-04
# Epoch 110/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6894e-04
# Epoch 111/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6553e-04
# Epoch 112/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.5973e-04
# Epoch 113/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.5472e-04
# Epoch 114/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.5010e-04
# Epoch 115/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.4568e-04
# Epoch 116/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4162e-04
# Epoch 117/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.3757e-04
# Epoch 118/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.3434e-04
# Epoch 119/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.3029e-04
# Epoch 120/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.2700e-04
# Epoch 121/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.2328e-04
# Epoch 122/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.2036e-04
# Epoch 123/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.1651e-04
# Epoch 124/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.1426e-04
# Epoch 125/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.1212e-04
# Epoch 126/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.0860e-04
# Epoch 127/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.0594e-04
# Epoch 128/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.0287e-04
# Epoch 129/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.0068e-04
# Epoch 130/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 9.7811e-05
# Epoch 131/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 9.5148e-05
# Epoch 132/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 9.2690e-05
# Epoch 133/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 9.0926e-05
# Epoch 134/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 8.9013e-05
# Epoch 135/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 8.6808e-05
# Epoch 136/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 8.4839e-05
# Epoch 137/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 8.2593e-05
# Epoch 138/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 8.1030e-05
# Epoch 139/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 7.9903e-05
# Epoch 140/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 7.7788e-05
# Epoch 141/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 7.5894e-05
# Epoch 142/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 7.4346e-05
# Epoch 143/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 7.3537e-05
# Epoch 144/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 7.1247e-05
# Epoch 145/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.9862e-05
# Epoch 146/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.8319e-05
# Epoch 147/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.6873e-05
# Epoch 148/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.5684e-05
# Epoch 149/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.4786e-05
# Epoch 150/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.3037e-05
# Epoch 151/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.1978e-05
# Epoch 152/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.1550e-05
# Epoch 153/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.9609e-05
# Epoch 154/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.8949e-05
# Epoch 155/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.7847e-05
# Epoch 156/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.6984e-05
# Epoch 157/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.5796e-05
# Epoch 158/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.4854e-05
# Epoch 159/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.4010e-05
# Epoch 160/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.3386e-05
# Epoch 161/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.1996e-05
# Epoch 162/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.1355e-05
# Epoch 163/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.1371e-05
# Epoch 164/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.9979e-05
# Epoch 165/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.9208e-05
# Epoch 166/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.8246e-05
# Epoch 167/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.7990e-05
# Epoch 168/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.6825e-05
# Epoch 169/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.6647e-05
# Epoch 170/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.5659e-05
# Epoch 171/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.5793e-05
# Epoch 172/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.4652e-05
# Epoch 173/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.3827e-05
# Epoch 174/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.3210e-05
# Epoch 175/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.2774e-05
# Epoch 176/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.2178e-05
# Epoch 177/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.1742e-05
# Epoch 178/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.1235e-05
# Epoch 179/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.0537e-05
# Epoch 180/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.0286e-05
# Epoch 181/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.9625e-05
# Epoch 182/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.9163e-05
# Epoch 183/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.8735e-05
# Epoch 184/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.8384e-05
# Epoch 185/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.7895e-05
# Epoch 186/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.7962e-05
# Epoch 187/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.7128e-05
# Epoch 188/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.6865e-05
# Epoch 189/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.6340e-05
# Epoch 190/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.6130e-05
# Epoch 191/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.5556e-05
# Epoch 192/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.5687e-05
# Epoch 193/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.5076e-05
# Epoch 194/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.4502e-05
# Epoch 195/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.4415e-05
# Epoch 196/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.4115e-05
# Epoch 197/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.3637e-05
# Epoch 198/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.3347e-05
# Epoch 199/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.3199e-05
# Epoch 200/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.2707e-05
# Epoch 201/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.2405e-05
# Epoch 202/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.2341e-05
# Epoch 203/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.1968e-05
# Epoch 204/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.1643e-05
# Epoch 205/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.1619e-05
# Epoch 206/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.1038e-05
# Epoch 207/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.0881e-05
# Epoch 208/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.0614e-05
# Epoch 209/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.1031e-05
# Epoch 210/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.0196e-05
# Epoch 211/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.0044e-05
# Epoch 212/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.9685e-05
# Epoch 213/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.9415e-05
# Epoch 214/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.9243e-05
# Epoch 215/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.8971e-05
# Epoch 216/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.9254e-05
# Epoch 217/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.8391e-05
# Epoch 218/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.8576e-05
# Epoch 219/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.8196e-05
# Epoch 220/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.7855e-05
# Epoch 221/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.7668e-05
# Epoch 222/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.7714e-05
# Epoch 223/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.7713e-05
# Epoch 224/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.7105e-05
# Epoch 225/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.7125e-05
# Epoch 226/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 2.6980e-05
# Epoch 227/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.6391e-05
# Epoch 228/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.6632e-05
# Epoch 229/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.6325e-05
# Epoch 230/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.6127e-05
# Epoch 231/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.6928e-05
# Epoch 232/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.5380e-05
# Epoch 233/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.6178e-05
# Epoch 234/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.5297e-05
# Epoch 235/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.5699e-05
# Epoch 236/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.5044e-05
# Epoch 237/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.4912e-05
# Epoch 238/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.4742e-05
# Epoch 239/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.4767e-05
# Epoch 240/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.4712e-05
# Epoch 241/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.4296e-05
# Epoch 242/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.4366e-05
# Epoch 243/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.4013e-05
# Epoch 244/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3949e-05
# Epoch 245/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3790e-05
# Epoch 246/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3677e-05
# Epoch 247/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3473e-05
# Epoch 248/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3400e-05
# Epoch 249/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3317e-05
# Epoch 250/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3153e-05
# Epoch 251/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3769e-05
# Epoch 252/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3101e-05
# Epoch 253/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.2896e-05
# Epoch 254/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.2590e-05
# Epoch 255/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.2702e-05
# Epoch 256/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.2430e-05
# Epoch 257/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3036e-05
# Epoch 258/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.2925e-05
# Epoch 259/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.2658e-05
# Epoch 260/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.2221e-05
# Epoch 261/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1893e-05
# Epoch 262/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1635e-05
# Epoch 263/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1508e-05
# Epoch 264/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1809e-05
# Epoch 265/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1320e-05
# Epoch 266/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1325e-05
# Epoch 267/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1264e-05
# Epoch 268/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1083e-05
# Epoch 269/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1026e-05
# Epoch 270/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.0786e-05
# Epoch 271/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.0785e-05
# Epoch 272/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.0422e-05
# Epoch 273/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.0530e-05
# Epoch 274/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.0312e-05
# Epoch 275/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.0163e-05
# Epoch 276/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.0072e-05
# Epoch 277/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9971e-05
# Epoch 278/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.0641e-05
# Epoch 279/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9638e-05
# Epoch 280/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9784e-05
# Epoch 281/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9733e-05
# Epoch 282/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9462e-05
# Epoch 283/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9591e-05
# Epoch 284/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9124e-05
# Epoch 285/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9113e-05
# Epoch 286/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9092e-05
# Epoch 287/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.8957e-05
# Epoch 288/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9003e-05
# Epoch 289/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.8774e-05
# Epoch 290/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.8623e-05
# Epoch 291/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.8527e-05
# Epoch 292/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9018e-05
# Epoch 293/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9316e-05
# Epoch 294/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9095e-05
# Epoch 295/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.8446e-05
# Epoch 296/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.8486e-05
# Epoch 297/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7974e-05
# Epoch 298/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.8145e-05
# Epoch 299/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7959e-05
# Epoch 300/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.8044e-05
# Epoch 301/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.8562e-05
# Epoch 302/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7377e-05
# Epoch 303/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7828e-05
# Epoch 304/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7367e-05
# Epoch 305/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7318e-05
# Epoch 306/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7221e-05
# Epoch 307/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7303e-05
# Epoch 308/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7215e-05
# Epoch 309/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6965e-05
# Epoch 310/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7164e-05
# Epoch 311/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6895e-05
# Epoch 312/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6699e-05
# Epoch 313/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6636e-05
# Epoch 314/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6815e-05
# Epoch 315/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6791e-05
# Epoch 316/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6224e-05
# Epoch 317/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6603e-05
# Epoch 318/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6279e-05
# Epoch 319/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6253e-05
# Epoch 320/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.5991e-05
# Epoch 321/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6062e-05
# Epoch 322/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6127e-05
# Epoch 323/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6254e-05
# Epoch 324/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6182e-05
# Epoch 325/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6075e-05

# %%
# loss 그래프 생성
plt.plot(history.history['loss'], label="loss")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# #### 테스트셋으로 cos을 사용한 이유는 훈련셋이 sin이므로 테스트셋도 sin을 사용하면 동일한 데이터를 사용하여 동일한 결과를 출력하므로 의미가 없어진다. 따라서 파형과 주기가 차이나는 cos을 이용해 테스트셋을 생성하여 테스트를 할 것이다.

# %%
# 테스트 데이터셋 생성
test_x = np.arange(10, # 시작은 10
                   20, # 끝은 20까지
                   0.1) # 0.1씩 증가
calc_y = np.cos(test_x) # 테스트 정답 데이터

# %%
# RNN 모델 예측 및 로그 저장
test_y = calc_y[:n_timesteps]
for i in range(len(test_x) - n_timesteps):
    net_input = test_y[i : i + n_timesteps]
    net_input = net_input.reshape((1, n_timesteps, n_features))
    train_y = model.predict(net_input, verbose=0)
    print(test_y.shape, train_y.shape, i, i + n_timesteps)
    test_y = np.append(test_y, train_y)
# Out:
# (15,) (1, 1) 0 15
# (16,) (1, 1) 1 16
# (17,) (1, 1) 2 17
# (18,) (1, 1) 3 18
# (19,) (1, 1) 4 19
# (20,) (1, 1) 5 20
# (21,) (1, 1) 6 21
# (22,) (1, 1) 7 22
# (23,) (1, 1) 8 23
# (24,) (1, 1) 9 24
# (25,) (1, 1) 10 25
# (26,) (1, 1) 11 26
# (27,) (1, 1) 12 27
# (28,) (1, 1) 13 28
# (29,) (1, 1) 14 29
# (30,) (1, 1) 15 30
# (31,) (1, 1) 16 31
# (32,) (1, 1) 17 32
# (33,) (1, 1) 18 33
# (34,) (1, 1) 19 34
# (35,) (1, 1) 20 35
# (36,) (1, 1) 21 36
# (37,) (1, 1) 22 37
# (38,) (1, 1) 23 38
# (39,) (1, 1) 24 39
# (40,) (1, 1) 25 40
# (41,) (1, 1) 26 41
# (42,) (1, 1) 27 42
# (43,) (1, 1) 28 43
# (44,) (1, 1) 29 44
# (45,) (1, 1) 30 45
# (46,) (1, 1) 31 46
# (47,) (1, 1) 32 47
# (48,) (1, 1) 33 48
# (49,) (1, 1) 34 49
# (50,) (1, 1) 35 50
# (51,) (1, 1) 36 51
# (52,) (1, 1) 37 52
# (53,) (1, 1) 38 53
# (54,) (1, 1) 39 54
# (55,) (1, 1) 40 55
# (56,) (1, 1) 41 56
# (57,) (1, 1) 42 57
# (58,) (1, 1) 43 58
# (59,) (1, 1) 44 59
# (60,) (1, 1) 45 60
# (61,) (1, 1) 46 61
# (62,) (1, 1) 47 62
# (63,) (1, 1) 48 63
# (64,) (1, 1) 49 64
# (65,) (1, 1) 50 65
# (66,) (1, 1) 51 66
# (67,) (1, 1) 52 67
# (68,) (1, 1) 53 68
# (69,) (1, 1) 54 69
# (70,) (1, 1) 55 70
# (71,) (1, 1) 56 71
# (72,) (1, 1) 57 72
# (73,) (1, 1) 58 73
# (74,) (1, 1) 59 74
# (75,) (1, 1) 60 75
# (76,) (1, 1) 61 76
# (77,) (1, 1) 62 77
# (78,) (1, 1) 63 78
# (79,) (1, 1) 64 79
# (80,) (1, 1) 65 80
# (81,) (1, 1) 66 81
# (82,) (1, 1) 67 82
# (83,) (1, 1) 68 83
# (84,) (1, 1) 69 84
# (85,) (1, 1) 70 85
# (86,) (1, 1) 71 86
# (87,) (1, 1) 72 87
# (88,) (1, 1) 73 88
# (89,) (1, 1) 74 89
# (90,) (1, 1) 75 90
# (91,) (1, 1) 76 91
# (92,) (1, 1) 77 92
# (93,) (1, 1) 78 93
# (94,) (1, 1) 79 94
# (95,) (1, 1) 80 95
# (96,) (1, 1) 81 96
# (97,) (1, 1) 82 97
# (98,) (1, 1) 83 98
# (99,) (1, 1) 84 99

# %%
# 예측 결과 그래프 그리기
plt.plot(test_x, calc_y, label="ground truth", color="orange")
plt.plot(test_x, test_y, label="predicitons", color="blue")
plt.legend(loc='upper left')
plt.ylim(-2, 2)
plt.show()
